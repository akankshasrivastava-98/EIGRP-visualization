# %%
import pandas as pd

# %%
df = pd.read_csv('EIGRP_H_U_Q_R_A.csv')

# %%
df.shape
# Out:
# (421, 7)

# %%
df.head(10)
# Out:
#    No.       Time                  Source        Destination Protocol  Length  \
# 0    1   0.000000  fe80::c601:3aff:fe44:0            ff02::a    EIGRP      94
# 1    2   1.619846  fe80::c602:3aff:fe44:0            ff02::a    EIGRP      94
# 2    3   2.186480  fe80::c600:3aff:fe44:0            ff02::a    EIGRP      94
# 3    4   2.780708  fe80::c601:3aff:fe44:0            ff02::1   ICMPv6      86
# 4    5   3.955231       c4:00:3a:44:00:00  c4:00:3a:44:00:00     LOOP      60
# 5    6   4.712731  fe80::c601:3aff:fe44:0            ff02::a    EIGRP      94
# 6    7   5.983466  fe80::c602:3aff:fe44:0            ff02::a    EIGRP      94
# 7    8   6.666735  fe80::c600:3aff:fe44:0            ff02::a    EIGRP      94
# 8    9   9.587181  fe80::c601:3aff:fe44:0            ff02::a    EIGRP      94
# 9   10  10.964115  fe80::c602:3aff:fe44:0            ff02::a    EIGRP      94
#
#                                           Info
# 0                                        Hello
# ...

# %%
eigrp = df[df['Protocol']=='EIGRP']

# %%
eigrp.shape
# Out:
# (327, 7)

# %%
eigrp.head(327)
# Out:
#      No.        Time                  Source             Destination Protocol  \
# 0      1    0.000000  fe80::c601:3aff:fe44:0                 ff02::a    EIGRP
# 1      2    1.619846  fe80::c602:3aff:fe44:0                 ff02::a    EIGRP
# 2      3    2.186480  fe80::c600:3aff:fe44:0                 ff02::a    EIGRP
# 5      6    4.712731  fe80::c601:3aff:fe44:0                 ff02::a    EIGRP
# 6      7    5.983466  fe80::c602:3aff:fe44:0                 ff02::a    EIGRP
# ..   ...         ...                     ...                     ...      ...
# 415  416  309.478928  fe80::c600:3aff:fe44:0  fe80::c602:3aff:fe44:0    EIGRP
# 416  417  311.678510  fe80::c601:3aff:fe44:0                 ff02::a    EIGRP
# 417  418  311.922110  fe80::c600:3aff:fe44:0                 ff02::a    EIGRP
# 418  419  312.035015  fe80::c602:3aff:fe44:0                 ff02::a    EIGRP
# 420  421  316.369866  fe80::c601:3aff:fe44:0                 ff02::a    EIGRP
#
#      Length         Info
# ...

# %%
print('\nEIGRP Packets Info\n', eigrp[['No.','Time', 'Info']])
# Out:
# EIGRP Packets Info
#       No.        Time         Info
# 0      1    0.000000        Hello
# 1      2    1.619846        Hello
# 2      3    2.186480        Hello
# 5      6    4.712731        Hello
# 6      7    5.983466        Hello
# ..   ...         ...          ...
# 415  416  309.478928  Hello (Ack)
# 416  417  311.678510        Hello
# 417  418  311.922110        Hello
# 418  419  312.035015        Hello
# 420  421  316.369866        Hello
#
# [327 rows x 3 columns]

# %%
info_eigrp = eigrp['Info'].to_list()
time = eigrp['Time'].to_list()

# %%
print('\nInfo Fields\n')
for info in info_eigrp:
    print(info)
#     flag =info.split('')
#     print('\n',flag[0])
# Out:
# Info Fields
#
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Update
# Hello (Ack)
# Hello (Ack)
# Hello
# Update
# Update
# Hello (Ack)
# Hello (Ack)
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Update
# Hello (Ack)
# Hello (Ack)
# Update
# Hello (Ack)
# Update
# Hello (Ack)
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Query
# Query
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(Time, info_eigrp)
plt.xlabel('Time Interval')
plt.ylabel('Flag')
plt.title('SIP Analysis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-59c332359857> in <module>
# ----> 1 plt.plot(Time, info_eigrp)
#       2 plt.xlabel('Time Interval')
#       3 plt.ylabel('Flag')
#       4 plt.title('SIP Analysis')
#       5 plt.show()
#
# NameError: name 'Time' is not defined
